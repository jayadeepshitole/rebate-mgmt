# %%
import pandas as pd

# %%
# !python --version
# Out:
# Python 3.11.8

# %%
pd.read_csv('sample_data/supplier_agreements.csv')
# Out:
#    supplier_id    supplier_name contract_start contract_end rebate_type  \
# 0            1  ABC Electronics     2023-01-01   2023-12-31      Volume
# 1            2   XYZ Appliances     2023-01-01   2023-12-31      Growth
# 2            3        123 Tools     2023-01-01   2023-12-31         Mix
# 3            4   Best Furniture     2023-01-01   2023-12-31   Retention
# 4            5     Tech Gadgets     2023-01-01   2023-12-31  Percentage
#
#    rebate_condition product_category  tier_1_threshold  tier_1_percentage  \
# 0      volume_based      Electronics           50000.0                2.0
# 1      growth_based       Appliances          100000.0                4.0
# 2         mix_based            Tools           75000.0                3.0
# 3   retention_based        Furniture               NaN                NaN
# 4  percentage_based          Gadgets               NaN                NaN
#
#    tier_2_threshold  tier_2_percentage  tier_3_threshold  tier_3_percentage  \
# ...
